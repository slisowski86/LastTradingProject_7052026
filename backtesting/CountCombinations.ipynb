# %%
import sys
sys.path.append('C:/Users/sliso/LastTradingProject_7052026/indicators')

# %%
# ----------------------------------------------------------------------
# 1. Signal decorator (must match your actual one)
# ----------------------------------------------------------------------
def signal(direction, signal_type="continuous", weight=1.0):
    def decorator(func):
        func._signal_meta = {
            'direction': direction,
            'type': signal_type,
            'weight': weight,
            'name': func.__name__
        }
        return func
    return decorator

#
# ----------------------------------------------------------------------
# 3. Utility: extract all signals from a list of indicator instances
# ----------------------------------------------------------------------
def get_signals(indicators):
    """Return list of dicts: {indicator, category, direction, type, method_name}"""
    signals = []
    for ind in indicators:
        ind_name = ind.__class__.__name__
        for method_name in dir(ind):
            method = getattr(ind, method_name)
            if callable(method) and hasattr(method, '_signal_meta'):
                meta = method._signal_meta
                signals.append({
                    'indicator': ind,
                    'indicator_name': ind_name,
                    'method_name': method_name,
                    'category': ind.category,
                    'direction': meta['direction'],
                    'type': meta['type'],
                })
    return signals

def build_signal_pool(indicators):
    """Group signals by (category, direction, type) -> list of (indicator, method_name)"""
    pool = defaultdict(list)
    for s in get_signals(indicators):
        key = (s['category'], s['direction'], s['type'])
        pool[key].append((s['indicator'], s['method_name']))
    return pool
('trend_direction', 'long', 'continuous') and ('trend_direction', 'short', 'continuous')
# ----------------------------------------------------------------------
# 4. Allowed patterns (full lists as defined earlier)
# ----------------------------------------------------------------------
PATTERNS_2_ENTRY_LONG = [
    (('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('divergence', 'long', 'discrete'))
]
PATTERNS_3_ENTRY_LONG = [
    (('momentum', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('momentum', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
]

PATTERNS_2_EXIT_LONG = [
    (('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('divergence', 'short', 'discrete'))
]
PATTERNS_3_EXIT_LONG = [
    (('momentum', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('momentum', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
]

PATTERNS_2_ENTRY_SHORT = [
    (('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('divergence', 'short', 'discrete'))
]
PATTERNS_3_ENTRY_SHORT = [
    (('momentum', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('momentum', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('momentum', 'short', 'continuous'), ('divergence', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'short', 'discrete')),
    (('trend_direction', 'short', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'short', 'discrete')),
]

PATTERNS_2_EXIT_SHORT = [
    (('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('divergence', 'long', 'discrete'))
]
PATTERNS_3_EXIT_SHORT = [
    (('momentum', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('momentum', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('volatility', 'both', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('momentum', 'long', 'continuous'), ('divergence', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('trend_strength', 'both', 'continuous'), ('momentum', 'long', 'discrete')),
    (('trend_direction', 'long', 'continuous'), ('trend_strength', 'both', 'continuous'), ('divergence', 'long', 'discrete')),
]

# ----------------------------------------------------------------------
# 5. Constraint helpers
# ----------------------------------------------------------------------
def divergence_map_from_indicators(indicators):
    """Build a dict: base_indicator_name -> list of divergence method names."""
    dm = defaultdict(list)
    for ind in indicators:
        base = ind.__class__.__name__
        for method_name in dir(ind):
            # assume divergence signals contain 'divergence' in name
            if 'div' in method_name.lower():
                dm[base].append(method_name)
    return dm

def has_divergence_conflict(selected_methods, divergence_map):
    """
    selected_methods: list of (indicator, method_name) tuples for a component.
    Returns True if any base indicator appears both as a regular signal
    and via a divergence signal in the same component.
    """
    regular_bases = set()
    for ind, meth in selected_methods:
        base = ind.__class__.__name__
        is_div = any(meth == d for d in divergence_map.get(base, []))
        if not is_div:
            regular_bases.add(base)
    for ind, meth in selected_methods:
        base = ind.__class__.__name__
        is_div = any(meth == d for d in divergence_map.get(base, []))
        if is_div and base in regular_bases:
            return True
    return False

# ----------------------------------------------------------------------
# 6. Generate all valid component combos (returns list of tuples of (indicator, method_name))
# ----------------------------------------------------------------------
def get_component_combos(indicators, patterns_2, patterns_3, divergence_map):
    """Return list of valid signal combinations for one component."""
    pool = build_signal_pool(indicators)
    combos = []

    # 2‑signal patterns
    for key1, key2 in patterns_2:
        list1 = pool.get(key1, [])
        list2 = pool.get(key2, [])
        if key1 == key2:
            n = len(list1)
            for i in range(n):
                ind1, m1 = list1[i]
                for j in range(i+1, n):
                    ind2, m2 = list1[j]
                    if ind1 == ind2:
                        continue
                    selected = [(ind1, m1), (ind2, m2)]
                    if not has_divergence_conflict(selected, divergence_map):
                        combos.append(selected)
        else:
            for (ind1, m1), (ind2, m2) in product(list1, list2):
                if ind1 == ind2:
                    continue
                selected = [(ind1, m1), (ind2, m2)]
                if not has_divergence_conflict(selected, divergence_map):
                    combos.append(selected)

    # 3‑signal patterns
    for pat in patterns_3:
        key1, key2, key3 = pat
        list1 = pool.get(key1, [])
        list2 = pool.get(key2, [])
        list3 = pool.get(key3, [])
        if key1 == key2 == key3:
            n = len(list1)
            for i in range(n):
                ind1, m1 = list1[i]
                for j in range(i+1, n):
                    ind2, m2 = list1[j]
                    if ind1 == ind2:
                        continue
                    for k in range(j+1, n):
                        ind3, m3 = list1[k]
                        if ind3 == ind1 or ind3 == ind2:
                            continue
                        selected = [(ind1, m1), (ind2, m2), (ind3, m3)]
                        if not has_divergence_conflict(selected, divergence_map):
                            combos.append(selected)
        elif key1 == key2:
            n1 = len(list1)
            for i in range(n1):
                ind1, m1 = list1[i]
                for j in range(i+1, n1):
                    ind2, m2 = list1[j]
                    if ind1 == ind2:
                        continue
                    for (ind3, m3) in list3:
                        if ind3 == ind1 or ind3 == ind2:
                            continue
                        selected = [(ind1, m1), (ind2, m2), (ind3, m3)]
                        if not has_divergence_conflict(selected, divergence_map):
                            combos.append(selected)
        elif key1 == key3:
            n1 = len(list1)
            for i in range(n1):
                ind1, m1 = list1[i]
                for k in range(i+1, n1):
                    ind3, m3 = list1[k]
                    if ind1 == ind3:
                        continue
                    for (ind2, m2) in list2:
                        if ind2 == ind1 or ind2 == ind3:
                            continue
                        selected = [(ind1, m1), (ind2, m2), (ind3, m3)]
                        if not has_divergence_conflict(selected, divergence_map):
                            combos.append(selected)
        elif key2 == key3:
            n2 = len(list2)
            for j in range(n2):
                ind2, m2 = list2[j]
                for k in range(j+1, n2):
                    ind3, m3 = list2[k]
                    if ind2 == ind3:
                        continue
                    for (ind1, m1) in list1:
                        if ind1 == ind2 or ind1 == ind3:
                            continue
                        selected = [(ind1, m1), (ind2, m2), (ind3, m3)]
                        if not has_divergence_conflict(selected, divergence_map):
                            combos.append(selected)
        else:
            # all keys different
            for (ind1, m1), (ind2, m2), (ind3, m3) in product(list1, list2, list3):
                if len({ind1, ind2, ind3}) != 3:
                    continue
                selected = [(ind1, m1), (ind2, m2), (ind3, m3)]
                if not has_divergence_conflict(selected, divergence_map):
                    combos.append(selected)
    return combos

# ----------------------------------------------------------------------
# 7. Count total strategies (with global usage limit)
# ----------------------------------------------------------------------
def count_total_strategies(indicators, max_global_usage=2, verbose=True):
    divergence_map = divergence_map_from_indicators(indicators)
    print("Building component combos...")
    el_combos = get_component_combos(indicators, PATTERNS_2_ENTRY_LONG, PATTERNS_3_ENTRY_LONG, divergence_map)
    xl_combos = get_component_combos(indicators, PATTERNS_2_EXIT_LONG,   PATTERNS_3_EXIT_LONG,   divergence_map)
    es_combos = get_component_combos(indicators, PATTERNS_2_ENTRY_SHORT, PATTERNS_3_ENTRY_SHORT, divergence_map)
    xs_combos = get_component_combos(indicators, PATTERNS_2_EXIT_SHORT,  PATTERNS_3_EXIT_SHORT,  divergence_map)

    if verbose:
        print(f"Entry long combos: {len(el_combos)}")
        print(f"Exit long combos:  {len(xl_combos)}")
        print(f"Entry short combos:{len(es_combos)}")
        print(f"Exit short combos: {len(xs_combos)}")
        print(f"Cartesian product size: {len(el_combos)*len(xl_combos)*len(es_combos)*len(xs_combos)}")

    # Enumerate all combinations and apply global usage limit
    total = 0
    for el in el_combos:
        for xl in xl_combos:
            # initial usage count
            usage = Counter()
            for ind, _ in el: usage[ind] += 1
            for ind, _ in xl: usage[ind] += 1
            if max(v for v in usage.values()) > max_global_usage:
                continue
            for es in es_combos:
                usage2 = usage.copy()
                for ind, _ in es: usage2[ind] += 1
                if max(v for v in usage2.values()) > max_global_usage:
                    continue
                for xs in xs_combos:
                    usage3 = usage2.copy()
                    for ind, _ in xs: usage3[ind] += 1
                    if max(v for v in usage3.values()) <= max_global_usage:
                        total += 1
                    # optional early exit? keep simple
    return total

# ----------------------------------------------------------------------
# 8. Example usage
# ----------------------------------------------------------------------

# %%
data=pd.read_csv("../df_test.csv", parse_dates=['Date'], index_col='Date')

# %%
rsi=RSI(data)
macd=MACD(data)
stoch=STOCH(data)
adx=ADX(data)
aroon=AROON(data)
bbwidth=BBWidth(data)
ehlersrefdiv=EhlersReflexDiv(data)
eit=EIT(data)
essv=ESSV(data)
garmanklass=GarmanKlass(data)
rsidiv=RsiDiv(data)
stochdiv=StochDiv(data)

# %%
indicators = [rsi, macd, stoch, adx, aroon, bbwidth, ehlersrefdiv, eit, essv, garmanklass, rsidiv, stochdiv ]

# %%
if __name__ == "__main__":
    # Create indicator instances (replace with your real ones)
    

    total = count_total_strategies(indicators, max_global_usage=2, verbose=True)
    print(f"\nTotal valid strategies (with global limit = 2): {total}")
# Out:
# Building component combos...
# Entry long combos: 418
# Exit long combos:  418
# Entry short combos:418
# Exit short combos: 418
# Cartesian product size: 30528476176
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       1 if __name__ == "__main__":
#       2     # Create indicator instances (replace with your real ones)
# ----> 5     total = count_total_strategies(indicators, max_global_usage=2, verbose=True)
#       6     print(f"\nTotal valid strategies (with global limit = 2): {total}")
#
# Cell In[2], line 313, in count_total_strategies(indicators, max_global_usage, verbose)
#     311     continue
#     312 for xs in xs_combos:
# --> 313     usage3 = usage2.copy()
#     314     for ind, _ in xs: usage3[ind] += 1
#     315     if max(v for v in usage3.values()) <= max_global_usage:
#
# File ~\anaconda3\Lib\collections\__init__.py:736, in Counter.copy(self)
#     734 def copy(self):
#     735     'Return a shallow copy.'
# --> 736     return self.__class__(self)
#
# File ~\anaconda3\Lib\collections\__init__.py:611, in Counter.__init__(self, iterable, **kwds)
#     600 '''Create a new, empty Counter object.  And if given, count elements
#     601 from an input iterable.  Or, initialize the count from another mapping
#     602 of elements to their counts.
#    (...)
#     608
#     609 '''
#     610 super().__init__()
# --> 611 self.update(iterable, **kwds)
#
# KeyboardInterrupt:
