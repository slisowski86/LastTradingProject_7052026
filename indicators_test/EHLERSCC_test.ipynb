# %%
import sys
sys.path.append('C:/Users/sliso/LastTradingProject_7052026/indicators/momentum')
sys.path.append('C:/Users/sliso/LastTradingProject_7052026/indicators')

# %%
import pandas as pd 
import numpy as np
from SignalDecorator import *
import talib as ta
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from EHLERSCC import EHLERSCC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 from SignalDecorator import *
#       4 import talib as ta
#       5 import plotly.graph_objects as go
#       6 from plotly.subplots import make_subplots
# ----> 7 from EHLERSCC import EHLERSCC
#
# ModuleNotFoundError: No module named 'EHLERSCC'

# %%
data=pd.read_csv("../df_test.csv", parse_dates=['Date'], index_col='Date')

# %%
ecc=EHLERSCC(data, period=20)
ecc.plot(100,400)
