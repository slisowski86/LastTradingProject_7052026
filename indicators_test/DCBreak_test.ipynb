# %%
import sys
sys.path.append('C:/Users/sliso/LastTradingProject_7052026/indicators')
sys.path.append('C:/Users/sliso/LastTradingProject_7052026/indicators/trend_direction')

# %%
import pandas as pd
import numpy as np
from numba import njit
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from SignalDecorator import signal  # your decorator
from DCBreak import DonchianChannelBreakout  # your indicator function

# %%
data=pd.read_csv("../df_test.csv", parse_dates=['Date'], index_col='Date')

# %%
dcb=DonchianChannelBreakout(data, period=20)
dcb.plot(100,400)
